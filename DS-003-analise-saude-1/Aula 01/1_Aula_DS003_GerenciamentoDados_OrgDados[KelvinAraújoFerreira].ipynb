# %% [markdown]
# ***
# # <font color=green size=10>**DS-002 - GERENCIAMENTO DE DADOS PARA ANÁLISE - AULA 01**</font>
# ***
#
# **1. Pergunta orientadora:** Quais conjuntos de atributos se associam ao elevado número de casos de dengue no Brasil?
#
# **2. Experiência da disciplina:** Obtenção de base de dados no Kaggle sobre Dengue, pré-processamento e análise exploratória de dados.
#
# **3. Base de Dados que utilizaremos:**
# [Link-Dados-Dengue-Brasil](https://www.kaggle.com/datasets/jimmyyyyyyy/dengue-in-brazil-2012-2021?select=State_Dengue_Model_Data_w_pop.csv). Apesar deste link, utilize a base que está no Moodle.

# %% [markdown]
# ## <font color=green size=6>**01. LEMBRETES IMPORTANTES**</font>

# %%
########################
### ALGUNS LEMBRETES ###
########################

# Este arquivo aqui no qual você está é chamado de notebook.

# Este texto aqui é um comentário.
# Ele sempre aparecerá nessa tonalidade de verde.

# O Python sabe identificar um comentário porque colocamos antes do texto o
# símbolo '#'.

# Notebooks são organizados em 2 tipos de "células":
# (1) Texto (ex.: campo acima) e (2) Código (ex. esta aqui).

# Veja um exemplo de código a seguir:

nome = input("Qual é o seu primeiro nome? Resposta: ")
resposta = input("Este é o seu 1º curso de Ciência de Dados? Se sim, escreva s. Para não, n. Resposta: ")
if resposta == 's':
    print(f"Muito prazer, ", nome,
          "! Bom contar contigo nesta disciplina, que é a sua primeira experiência com Ciência de Dados :)")
else:
    print(f"Muito prazer {nome}! Bom contar contigo nesta disciplina :)")

# Para executar o código, acione as teclas "CTRL + ENTER" ou
# use o botão "Run", com o símbolo de 'Play'.

# Note que, após a execução do código, nenhum comentário foi exibido abaixo.

# Atenção: não se esqueça de que códigos devem ser organizados como
# sequências de comandos.
# Out:
# Qual é o seu primeiro nome? Resposta: Kelvin
# Este é o seu 1º curso de Ciência de Dados? Se sim, escreva s. Para não, n. Resposta: n
# Muito prazer Kelvin! Bom contar contigo nesta disciplina :)

# %% [markdown]
# ## <font color=green size=6>**02. PREPARANDO O AMBIENTE DE TRABALHO**</font>

# %% [markdown]
# 🤓 **Hoje, usaremos uma sequência de comandos que nos permitirá analisar dados com Python.**
#
# * O nosso primeiro passo será fazer o download de uma base de dados sobre casos de dengue no Brasil. O link é o mesmo que está na primeira célula: [Link-Dados-Dengue-Brasil](https://www.kaggle.com/datasets/jimmyyyyyyy/dengue-in-brazil-2012-2021?select=State_Dengue_Model_Data_w_pop.csv). Apesar deste link, utilize a base que está no Moodle.
#
# **Siga os passos a seguir:**
#
# 1. Caso esteja no Google Colab, faça upload da base de dados. Na sequência, obtenha o caminho do arquivo. Ao passar o cursor sobre o arquivo, você verá três pontinhos na vertical, logo na direta do arquivo selecionado. Clique neles e, então, você verá a opção de `Copiar caminho`. Veha a imagem abaixo.
#
# ![](https://cdn1.gnarususercontent.com.br/1/547588/9fc47f1b-b54c-4b42-a6e3-a14d3d917ccd.png)
#
# 2. Se estiver no Jupyter Notebook, salve o arquivo *.csv no local que desejar, na máquina em que estiver trabalhando. Copie o caminho do arquivo. Veja o exemplo abaixo.
#
# ![](https://www.wikihow.com/images/thumb/5/51/Find-a-File%27s-Path-on-Windows-Step-5.jpg/v4-728px-Find-a-File%27s-Path-on-Windows-Step-5.jpg.webp)
#
# *Esta imagem de exemplo é de um site que ensina como obter esse caminho.*
# *Acesse o link abaixo, caso precise de mais ajuda.*
#
# [Link-WikiHow-Caminho-Arquivo-Windows](https://pt.wikihow.com/Encontrar-o-Caminho-de-um-Arquivo-no-Windows)

# %% [markdown]
# ## <font color=green size=6>**03. PRÉ-PROCESSAMENTO**</font>

# %% [markdown]
# ##### **01. Importe a biblioteca Pandas. Ela possui códigos prontos, para que possamos abrir com o Python a base de dados.**
# > Padrão dominante para aplicações Python orientadas a dados. Possui duas estruturas de dados: *Series*, que trabalha com informações em 1 Dimensão, e *DataFrame*, que possui 2 Dimensões. Na prática, o DataFrame é uma coleção de objetos Series.
#
# *Neste [vídeo](https://www.youtube.com/watch?v=yCtiqMRt4TQ), vemos uma síntese sobre o que é e qual o grau de importância do Pandas.*
#
# > O `pd` é um apelido curto, para que possamos nos referir a esta biblioteca e usar os seus recursos em nosso código.

# %%
import pandas as pd

# %% [markdown]
# ##### **02. Obtenha a base de dados.**
# > O `r` antes do caminho do arquivo garante que todos os caracteres desse caminho sejam interpretados como texto. Na ausência dele, a barra invertida é interpretada como caractere de escape, cuja ação depende da próxima letra. Por exemplo: `\n` leva o Python a pular uma linha.

# %%
dados = pd.read_csv(r'/content/dengue.csv')

# %% [markdown]
# ##### **03. Verifique o conteúdo da base de dados, para estar seguro de que os dados foram obtidos adequadamente.**
# > Podemos ter uma noção do conteúdo do banco, pedindo para o Python nos mostrar os seus 5 primeiros registros por meio do atributo `.head()`.

# %%
dados.head()
# Out:
#    Year State  Mean_Tmp  Min_Tmp  Max_Tmp  Percipitation  Change_Tmp  \
# 0  2012  Acre     25.74    20.48    31.05        1851.90       10.57
# 1  2013  Acre     25.61    20.40    30.86        1909.14       10.46
# 2  2014  Acre     25.78    20.57    31.04        2243.00       10.47
# 3  2015  Acre     26.22    20.88    31.62        1895.83       10.74
# 4  2016  Acre     26.16    20.66    31.71        1874.84       11.05
#
#    State_ID  Cases Region  State_Area(km2)  Population
# 0      12.0     22      N         164124.0      758786
# 1      12.0   9229      N         164124.0      776463
# 2      12.0  36795      N         164124.0      790101
# 3      12.0  14320      N         164124.0      803513
# 4      12.0   9237      N         164124.0      816687

# %% [markdown]
# > Podemos ter uma ideia dos últimos 5 itens do nosso banco, pedindo isso ao Python com o seguinte comando.

# %%
dados.tail()
# Out:
#      Year      State  Mean_Tmp  Min_Tmp  Max_Tmp  Percipitation  Change_Tmp  \
# 255  2018  Tocantins     27.53    21.81    33.29        1749.54       11.48
# 256  2019  Tocantins     27.92    21.93    33.96        1271.12       12.03
# 257  2020  Tocantins     27.74    21.89    33.65        1729.92       11.76
# 258  2021  Tocantins     27.33    21.62    33.09        1717.39       11.47
# 259  2021        NaN     27.33    21.62    33.09        1717.39       11.47
#
#      State_ID  Cases Region  State_Area(km2)  Population
# 255      17.0   8236      N         277721.0     1555229
# 256      17.0  30901      N         277721.0     1572866
# 257      17.0   5625      N         277721.0     1590248
# 258      17.0      1      N         277721.0     1607363
# 259       NaN      1      N         277721.0     1607363

# %% [markdown]
# **Informações importantes sobre a base de dados:**
#
# 🤔**O que signica cada coluna:**
#
# - Year: ano entre 2012 e 2021
# - State: estado brasileiro
# - Mean_Tmp: temperatura média em graus Celsius no ano
# - Min_Tmp: temperatura mínima em graus Celsius no ano
# - Max_Tmp: temperatura máxima em graus Celsius no ano
# - Percipitation: precipitação anual em milímetros
# - Change_Tmp: temp. máx. anual menos temp. mín. anual em graus Celsius
# - State_ID: número de identificação do estado brasileiro
# - Cases: número de casos de dengue
# - Region: região brasileira (Norte = N, Nordeste = NE, Centro-Oeste = CO, Sudeste = SE, Sul = S)
# - State_Area(km2): área em km2 do estado
# - Population: estimativa da população total

# %% [markdown]
# 💻**Como o Pandas guarda os nossos dados:**
#
# - O pandas armazena o nosso banco como um `DataFrame`, que é uma estrutura bi-dimensional, que pode contar diversos tipos de dados, sendo os elementos rotulados.
# - Os rótulos das linhas estão no atributo *index*, que são os números de 0 em diante que podem ser vistos acima, na extrema esquerda da tabela. Já os rótulos de colunas ficam no atributo *columns*.
# - Daqui em diante, vamos usar o termo `DataFrame` como substituto de banco de dados.

# %% [markdown]
# ##### **04. Crie uma cópia do DataFrame original.**
# > Esta é uma boa prática, para evitarmos o risco de perder ou modificar algo da base original. Nessa cópia, é útil deixar apenas as variáveis que iremos analisar.

# %%
df_dengue = pd.DataFrame(dados, columns = ['Year', 'State', 'Population', 'Region', 'Min_Tmp',
                                               'Max_Tmp', 'Change_Tmp', 'Mean_Tmp', 'Percipitation','Cases'])

# %%
df_dengue_nova_copia = pd.DataFrame(dados)

# %%
df_dengue_nova_copia.head()
# Out:
#    Year State  Mean_Tmp  Min_Tmp  Max_Tmp  Percipitation  Change_Tmp  \
# 0  2012  Acre     25.74    20.48    31.05        1851.90       10.57
# 1  2013  Acre     25.61    20.40    30.86        1909.14       10.46
# 2  2014  Acre     25.78    20.57    31.04        2243.00       10.47
# 3  2015  Acre     26.22    20.88    31.62        1895.83       10.74
# 4  2016  Acre     26.16    20.66    31.71        1874.84       11.05
#
#    State_ID  Cases Region  State_Area(km2)  Population
# 0      12.0     22      N         164124.0      758786
# 1      12.0   9229      N         164124.0      776463
# 2      12.0  36795      N         164124.0      790101
# 3      12.0  14320      N         164124.0      803513
# 4      12.0   9237      N         164124.0      816687

# %% [markdown]
# ##### **05. Consulte o banco copiado, para verificar se está correto.**

# %%
df_dengue.head()
# Out:
#    Year State  Population Region  Min_Tmp  Max_Tmp  Change_Tmp  Mean_Tmp  \
# 0  2012  Acre      758786      N    20.48    31.05       10.57     25.74
# 1  2013  Acre      776463      N    20.40    30.86       10.46     25.61
# 2  2014  Acre      790101      N    20.57    31.04       10.47     25.78
# 3  2015  Acre      803513      N    20.88    31.62       10.74     26.22
# 4  2016  Acre      816687      N    20.66    31.71       11.05     26.16
#
#    Percipitation  Cases
# 0        1851.90     22
# 1        1909.14   9229
# 2        2243.00  36795
# 3        1895.83  14320
# 4        1874.84   9237

# %%
df_dengue
# Out:
#      Year      State  Population Region  Min_Tmp  Max_Tmp  Change_Tmp  \
# 0    2012       Acre      758786      N    20.48    31.05       10.57
# 1    2013       Acre      776463      N    20.40    30.86       10.46
# 2    2014       Acre      790101      N    20.57    31.04       10.47
# 3    2015       Acre      803513      N    20.88    31.62       10.74
# 4    2016       Acre      816687      N    20.66    31.71       11.05
# ..    ...        ...         ...    ...      ...      ...         ...
# 255  2018  Tocantins     1555229      N    21.81    33.29       11.48
# 256  2019  Tocantins     1572866      N    21.93    33.96       12.03
# 257  2020  Tocantins     1590248      N    21.89    33.65       11.76
# 258  2021  Tocantins     1607363      N    21.62    33.09       11.47
# 259  2021        NaN     1607363      N    21.62    33.09       11.47
#
#      Mean_Tmp  Percipitation  Cases
# 0       25.74        1851.90     22
# 1       25.61        1909.14   9229
# ...

# %% [markdown]
# ##### **06. Verifique quais são os estados que estão presentes no banco de dados.**

# %%
df_dengue['State']
# Out:
# 0           Acre
# 1           Acre
# 2           Acre
# 3           Acre
# 4           Acre
#          ...
# 255    Tocantins
# 256    Tocantins
# 257    Tocantins
# 258    Tocantins
# 259          NaN
# Name: State, Length: 260, dtype: object

# %% [markdown]
# > Posso conseguir uma lista dos dados de uma coluna sem repetições de valores.

# %%
df_dengue['State'].unique()
# Out:
# array(['Acre', 'Alagoas', 'Amapa', 'Amazonas', 'Bahia', 'Ceara',
#        'Distrito Federal', 'Espirito Santo', 'Goias', 'Maranhao',
#        'Mato Grosso', 'Mato Grosso Do Sul', 'Minas Gerais', 'Para',
#        'Paraiba', nan, 'Parana', 'Pernambuco', 'Piaui', 'Rio De Janeiro',
#        'Rio Grande Do Norte', 'Rio Grande Do Sul', 'Rondonia', 'Roraima',
#        'Santa Catarina', 'Sao Paulo', 'Sergipe', 'Tocantins'],
#       dtype=object)

# %% [markdown]
# ##### **07. Descubra os casos de NaN e NULL na base de dados.**
#
# > Podem ocorrer casos de valores que não são números e de valores nulos. A depender de casa situação, pode ser necessário remover ambos. É o que faremos aqui.

# %%
# Casos de valores ausentes
df_dengue.isnull().any()
# Out:
# Year             False
# State             True
# Population       False
# Region           False
# Min_Tmp          False
# Max_Tmp          False
# Change_Tmp       False
# Mean_Tmp         False
# Percipitation    False
# Cases            False
# dtype: bool

# %%
# Casos de valores ausentes
# Exibição das linhas
df_dengue[df_dengue.isnull().any(axis=1)]
# Out:
#      Year State  Population Region  Min_Tmp  Max_Tmp  Change_Tmp  Mean_Tmp  \
# 141  2021   NaN     1607363      N    21.62    33.09       11.47     27.33
# 259  2021   NaN     1607363      N    21.62    33.09       11.47     27.33
#
#      Percipitation  Cases
# 141        1717.39      1
# 259        1717.39      1

# %%
# Casos de valores que não são números
df_dengue.isna().any()
# Out:
# Year             False
# State             True
# Population       False
# Region           False
# Min_Tmp          False
# Max_Tmp          False
# Change_Tmp       False
# Mean_Tmp         False
# Percipitation    False
# Cases            False
# dtype: bool

# %%
# Casos de valores que não são números
# Exibição das linhas
df_dengue[df_dengue.isna().any(axis=1)]
# Out:
#      Year State  Population Region  Min_Tmp  Max_Tmp  Change_Tmp  Mean_Tmp  \
# 141  2021   NaN     1607363      N    21.62    33.09       11.47     27.33
# 259  2021   NaN     1607363      N    21.62    33.09       11.47     27.33
#
#      Percipitation  Cases
# 141        1717.39      1
# 259        1717.39      1

# %% [markdown]
# ##### **08. Remova todos os casos de NaN do banco de dados.**

# %%
df_dengue = df_dengue.dropna()

# %%
df_dengue.dropna(inplace=True)
# Out:
# <ipython-input-17-bc48439d8c34>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dengue.dropna(inplace=True)

# %% [markdown]
# ##### **09. Verifique se ainda existem casos de NaN e avalie como ficou a base de dados.**

# %%
df_dengue[df_dengue.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Year, State, Population, Region, Min_Tmp, Max_Tmp, Change_Tmp, Mean_Tmp, Percipitation, Cases]
# Index: []

# %%
df_dengue.tail()
# Out:
#      Year      State  Population Region  Min_Tmp  Max_Tmp  Change_Tmp  \
# 254  2017  Tocantins     1550194      N    21.96    33.66       11.70
# 255  2018  Tocantins     1555229      N    21.81    33.29       11.48
# 256  2019  Tocantins     1572866      N    21.93    33.96       12.03
# 257  2020  Tocantins     1590248      N    21.89    33.65       11.76
# 258  2021  Tocantins     1607363      N    21.62    33.09       11.47
#
#      Mean_Tmp  Percipitation  Cases
# 254     27.79        1320.86  14882
# 255     27.53        1749.54   8236
# 256     27.92        1271.12  30901
# 257     27.74        1729.92   5625
# 258     27.33        1717.39      1

# %% [markdown]
# 💰**Bônus:**
# > Se você quisesse, poderia mudar os nomes das colunas do seu DataFrame. Para isso, basta usar o método `.rename()`.

# %% [markdown]
# ##### **10. Inspecione algumas características do seu DataFrame.**

# %%
df_dengue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 258 entries, 0 to 258
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           258 non-null    int64
#  1   State          258 non-null    object
#  2   Population     258 non-null    int64
#  3   Region         258 non-null    object
#  4   Min_Tmp        258 non-null    float64
#  5   Max_Tmp        258 non-null    float64
#  6   Change_Tmp     258 non-null    float64
#  7   Mean_Tmp       258 non-null    float64
#  8   Percipitation  258 non-null    float64
#  9   Cases          258 non-null    int64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 22.2+ KB

# %% [markdown]
# ##### **11. Verifique o tamanho do seu DataFrame.**

# %%
df_dengue.shape
# Out:
# (258, 10)

# %% [markdown]
# ##### **12. Crie uma nova coluna chamada SeveralCases, que irá conter apenas dois valores: 0, quando o número de casos em uma linha estiver abaixo da mediana do conjunto de dados e 1, quando for maior.**

# %%
mediana = df_dengue['Cases'].median()
print("A mediana é igual a ", mediana)
# Out:
# A mediana é igual a  11370.0

# %%
def ident_se_muitos_casos(casos):
  if casos > mediana:
    return 1
  else:
    return 0

df_dengue['SeveralCases'] = df_dengue['Cases'].apply(ident_se_muitos_casos)
# Out:
# <ipython-input-23-3220a2a7c839>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dengue['SeveralCases'] = df_dengue['Cases'].apply(ident_se_muitos_casos)

# %% [markdown]
# ##### **13. Consulte o DataFrame para examinar se a coluna foi criada.**

# %%
df_dengue
# Out:
#      Year      State  Population Region  Min_Tmp  Max_Tmp  Change_Tmp  \
# 0    2012       Acre      758786      N    20.48    31.05       10.57
# 1    2013       Acre      776463      N    20.40    30.86       10.46
# 2    2014       Acre      790101      N    20.57    31.04       10.47
# 3    2015       Acre      803513      N    20.88    31.62       10.74
# 4    2016       Acre      816687      N    20.66    31.71       11.05
# ..    ...        ...         ...    ...      ...      ...         ...
# 254  2017  Tocantins     1550194      N    21.96    33.66       11.70
# 255  2018  Tocantins     1555229      N    21.81    33.29       11.48
# 256  2019  Tocantins     1572866      N    21.93    33.96       12.03
# 257  2020  Tocantins     1590248      N    21.89    33.65       11.76
# 258  2021  Tocantins     1607363      N    21.62    33.09       11.47
#
#      Mean_Tmp  Percipitation  Cases  SeveralCases
# 0       25.74        1851.90     22             0
# ...

# %% [markdown]
# ##### **14. Verifique com quantos valores de cada classe (1 e 0) da coluna SeveralCases o seu DataFrame ficou.**

# %%
df_dengue['SeveralCases'].value_counts()
# Out:
# SeveralCases
# 0    129
# 1    129
# Name: count, dtype: int64

# %% [markdown]
# ## <font color=green size=6>**TAREFA 01**</font>

# %% [markdown]
# *Esta é a atividade que você fará nas suas horas de aula on-line.*
#
# **01. Usando a base de dados sobre casos de dengue no Brasil, `df_dengue`, renomeie as colunas, com base na dica fornecida acima. Os novos nomes podem ser definidos por você, mas precisam ser em português. Entregue o seu notebook no Moodle, por meio de um link de compartilhamento.**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ***
# # <font color=green size=10>**DS-002 - GERENCIAMENTO DE DADOS PARA ANÁLISE - AULA 02**</font>
# ***

# %%
# @title Reiniciando o notebook
import pandas as pd

dados = pd.read_csv(r'/content/dengue.csv')

df_dengue = pd.DataFrame(dados, columns = ['Year',
                                           'State',
                                           'Population',
                                           'Region',
                                           'Min_Tmp',
                                           'Max_Tmp',
                                           'Change_Tmp',
                                           'Mean_Tmp',
                                           'Percipitation',
                                           'Cases'])
df_dengue = df_dengue.dropna()

mediana = df_dengue['Cases'].median()
def ident_se_muitos_casos(casos):
  if casos > mediana:
    return 1
  else:
    return 0

df_dengue['SeveralCases'] = df_dengue['Cases'].apply(ident_se_muitos_casos)

# %% [markdown]
# ##### **15. Crie uma nova coluna chamada FromMainStates para sabermos quais são as linhas do banco relativas ao estados que se destacam em relação à quantidade de casos de dengue: Distrito Federal, Minas Gerais e Paraná.**

# %%
df_dengue.head()
# Out:
#    Year State  Population Region  Min_Tmp  Max_Tmp  Change_Tmp  Mean_Tmp  \
# 0  2012  Acre    758786.0      N    20.48    31.05       10.57     25.74
# 1  2013  Acre    776463.0      N    20.40    30.86       10.46     25.61
# 2  2014  Acre    790101.0      N    20.57    31.04       10.47     25.78
# 3  2015  Acre    803513.0      N    20.88    31.62       10.74     26.22
# 4  2016  Acre    816687.0      N    20.66    31.71       11.05     26.16
#
#    Percipitation  Cases  SeveralCases
# 0        1851.90     22             0
# 1        1909.14   9229             0
# 2        2243.00  36795             1
# 3        1895.83  14320             1
# 4        1874.84   9237             0

# %%
df_dengue['FromMainStates'] = df_dengue['State'].apply(nova_estado_para_cod)

def nova_estado_para_cod(estado):
  if estado == 'Distrito Federal':
    return 1
  elif estado == 'Minas Gerais':
    return 2
  elif estado == 'Parana':
    return 3
  else:
    return 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-1e3694753e9b> in <cell line: 1>()
# ----> 1 df_dengue['FromMainStates'] = df_dengue['State'].apply(nova_estado_para_cod)
#       2
#       3 def nova_estado_para_cod(estado):
#       4   if estado == 'Distrito Federal':
#       5     return 1
#
# NameError: name 'nova_estado_para_cod' is not defined

# %%
df_dengue['FromMainStates'] = df_dengue['State'].apply(estado_para_cod)

def estado_para_cod(estado):
  if estado == 'Distrito Federal':
    return 1
  elif estado == 'Minas Gerais':
    return 2
  elif estado == 'Parana':
    return 3
  else:
    return 0

# %%
df_dengue.head(2)
# Out:
#    Year State  Population Region  Min_Tmp  Max_Tmp  Change_Tmp  Mean_Tmp  \
# 0  2012  Acre    758786.0      N    20.48    31.05       10.57     25.74
# 1  2013  Acre    776463.0      N    20.40    30.86       10.46     25.61
#
#    Percipitation  Cases  SeveralCases  FromMainStates
# 0        1851.90     22             0               0
# 1        1909.14   9229             0               0

# %%
def nova_estado_para_cod(estado):
  if estado == 'Distrito Federal':
    return 1
  elif estado == 'Minas Gerais':
    return 2
  elif estado == 'Parana':
    return 3
  else:
    return 0

df_dengue['FromMainStates'] = df_dengue['State'].apply(nova_estado_para_cod)

# %% [markdown]
# ##### **16. Consulte o banco para verificar se esta coluna foi criada.**

# %%
df_dengue.sample(5)
# Out:
#      Year         State  Population Region  Min_Tmp  Max_Tmp  Change_Tmp  \
# 243  2015       Sergipe   2242937.0     NE    21.24    30.66        9.42
# 90   2015      Maranhao   6904241.0     NE    22.42    33.01       10.59
# 117  2013  Minas Gerais  20593356.0     SE    16.84    28.50       11.66
# 253  2016     Tocantins   1532902.0      N    22.12    33.93       11.81
# 121  2017  Minas Gerais  21119536.0     SE    16.87    29.01       12.14
#
#      Mean_Tmp  Percipitation   Cases  SeveralCases  FromMainStates
# 243     25.92         723.42   14773             1               0
# 90      27.69        1087.29    9711             0               0
# 117     22.65        1380.75  501899             1               2
# 253     28.00        1282.61   19882             1               0
# 121     22.92         974.72   61532             1               2

# %% [markdown]
# ##### **17. Pesquise por todos os valores iguais a `Parana` para ver se, na última coluna, estão relacionados ao número 3.**

# %%
df_dengue.query("'Parana' in State")
# Out:
#      Year   State  Population Region  Min_Tmp  Max_Tmp  Change_Tmp  Mean_Tmp  \
# 145  2012  Parana  10577755.0      S    14.70    26.06       11.36     20.36
# 146  2013  Parana  10997465.0      S    14.13    25.16       11.03     19.62
# 147  2014  Parana  11081692.0      S    15.22    26.04       10.82     20.60
# 148  2015  Parana  11163018.0      S    15.40    25.82       10.42     20.59
# 149  2016  Parana  11242720.0      S    14.39    25.45       11.06     19.90
# 150  2017  Parana  11320892.0      S    15.12    25.95       10.83     20.51
# 151  2018  Parana  11348937.0      S    14.79    25.81       11.02     20.27
# 152  2019  Parana  11433957.0      S    15.35    26.43       11.08     20.86
# 153  2020  Parana  11516840.0      S    14.64    26.49       11.85     20.54
# 154  2021  Parana  11597484.0      S    14.46    26.04       11.58     20.22
#
#      Percipitation   Cases  SeveralCases  FromMainStates
# 145        1524.60      46             0               3
# ...

# %%
df_dengue.query('"Parana" in State')
# Out:
#      Year   State  Population Region  Min_Tmp  Max_Tmp  Change_Tmp  Mean_Tmp  \
# 145  2012  Parana  10577755.0      S    14.70    26.06       11.36     20.36
# 146  2013  Parana  10997465.0      S    14.13    25.16       11.03     19.62
# 147  2014  Parana  11081692.0      S    15.22    26.04       10.82     20.60
# 148  2015  Parana  11163018.0      S    15.40    25.82       10.42     20.59
# 149  2016  Parana  11242720.0      S    14.39    25.45       11.06     19.90
# 150  2017  Parana  11320892.0      S    15.12    25.95       10.83     20.51
# 151  2018  Parana  11348937.0      S    14.79    25.81       11.02     20.27
# 152  2019  Parana  11433957.0      S    15.35    26.43       11.08     20.86
# 153  2020  Parana  11516840.0      S    14.64    26.49       11.85     20.54
# 154  2021  Parana  11597484.0      S    14.46    26.04       11.58     20.22
#
#      Percipitation   Cases  SeveralCases  FromMainStates
# 145        1524.60      46             0               3
# ...

# %%
df_dengue.query(''Parana' in State')
# Out:
#   File "<ipython-input-55-44be3c568b75>", line 1
#     df_dengue.query(''Parana' in State')
#                     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ##### **18. Conte quantas vezes `Parana` aparece no DataFrame.**

# %%
df_dengue.query("'Parana' in State").State
# Out:
# 145    Parana
# 146    Parana
# 147    Parana
# 148    Parana
# 149    Parana
# 150    Parana
# 151    Parana
# 152    Parana
# 153    Parana
# 154    Parana
# Name: State, dtype: object

# %%
df_dengue.query("'Parana' in State").State.value_counts()
# Out:
# State
# Parana    10
# Name: count, dtype: int64

# %% [markdown]
# ##### **19. Pesquise por todos os valores iguais a 3 na coluna que criamos.**
#
# > É sempre bom ter certeza de que não fizemos nada de errado. Portanto, utilizar diferentes estratégias para examinar os dados é importante.

# %%
df_dengue.query("FromMainStates == 3")
# Out:
#      Year   State  Population Region  Min_Tmp  Max_Tmp  Change_Tmp  Mean_Tmp  \
# 145  2012  Parana  10577755.0      S    14.70    26.06       11.36     20.36
# 146  2013  Parana  10997465.0      S    14.13    25.16       11.03     19.62
# 147  2014  Parana  11081692.0      S    15.22    26.04       10.82     20.60
# 148  2015  Parana  11163018.0      S    15.40    25.82       10.42     20.59
# 149  2016  Parana  11242720.0      S    14.39    25.45       11.06     19.90
# 150  2017  Parana  11320892.0      S    15.12    25.95       10.83     20.51
# 151  2018  Parana  11348937.0      S    14.79    25.81       11.02     20.27
# 152  2019  Parana  11433957.0      S    15.35    26.43       11.08     20.86
# 153  2020  Parana  11516840.0      S    14.64    26.49       11.85     20.54
# 154  2021  Parana  11597484.0      S    14.46    26.04       11.58     20.22
#
#      Percipitation   Cases  SeveralCases  FromMainStates
# 145        1524.60      46             0               3
# ...

# %% [markdown]
# ##### **20. Some todos os valores da coluna FromMainStates, que são iguais a 3, para termos certeza de que não temos mais do que 10 registros iguais a 3.**

# %%
df_dengue.query('FromMainStates == 3').FromMainStates.sum()
# Out:
# 30

# %% [markdown]
# ##### **21. Crie uma coluna FromNNECOorSSE que irá conter o valor 1 se a linha for das regiões N, NE ou CO e 2 se for das regiões S ou SE e verifique se o DataFrame ficou correto.**

# %%
def div_duas_regioes(regiao):
  if regiao == 'N' or regiao == 'NE' or regiao == 'CO':
    return 1
  else:
    return 2

df_dengue['FromNNECOorSSE'] = df_dengue['Region'].apply(div_duas_regioes)

# %%
df_dengue.sample(10)
# Out:
#      Year                State  Population Region  Min_Tmp  Max_Tmp  \
# 39   2013                Bahia  15044137.0     NE    19.67    30.38
# 189  2018  Rio Grande Do Norte   3479010.0     NE    21.86    32.47
# 16   2018              Alagoas   3322820.0     NE    20.62    30.11
# 107  2013   Mato Grosso Do Sul   2587269.0     CO    19.07    30.37
# 80   2015                Goias   6610681.0     CO    19.67    31.67
# 52   2016                Ceara   8963663.0     NE    21.91    32.77
# 224  2016       Santa Catarina   6910553.0      S    12.54    23.28
# 158  2015           Pernambuco   9345173.0     NE    20.00    30.84
# 17   2019              Alagoas   3337357.0     NE    20.74    30.26
# 48   2012                Ceara   8606005.0     NE    21.53    32.18
#
#      Change_Tmp  Mean_Tmp  Percipitation   Cases  SeveralCases  \
# 39        10.71     25.00         829.99   84970             1
# 189       10.61     27.14         662.32   30224             1
# ...

# %% [markdown]
# ##### **22. Crie uma nova coluna com o cálculo do percentual de casos na população e verifique se o DataFrame ficou correto.**

# %%
# Não é o melhor método de criar colunas, mas está funcionando
df_dengue['%CasesInPop'] = (df_dengue['Cases'] / df_dengue['Population'])*100

# %%
df_dengue.head(7)
# Out:
#    Year State  Population Region  Min_Tmp  Max_Tmp  Change_Tmp  Mean_Tmp  \
# 0  2012  Acre    758786.0      N    20.48    31.05       10.57     25.74
# 1  2013  Acre    776463.0      N    20.40    30.86       10.46     25.61
# 2  2014  Acre    790101.0      N    20.57    31.04       10.47     25.78
# 3  2015  Acre    803513.0      N    20.88    31.62       10.74     26.22
# 4  2016  Acre    816687.0      N    20.66    31.71       11.05     26.16
# 5  2017  Acre    829619.0      N    20.47    31.64       11.17     26.03
# 6  2018  Acre    869265.0      N    20.26    30.99       10.73     25.60
#
#    Percipitation  Cases  SeveralCases  FromMainStates  FromNNECOorSSE  \
# 0        1851.90     22             0               0               1
# 1        1909.14   9229             0               0               1
# 2        2243.00  36795             1               0               1
# 3        1895.83  14320             1               0               1
# ...

# %% [markdown]
# 💰**Bônus - Identificação dos dados relativos a um valor máximo**

# %%
df_dengue.loc[df_dengue['%CasesInPop'].idxmax()]
# Out:
# Year                  2014
# State                 Acre
# Population        790101.0
# Region                   N
# Min_Tmp              20.57
# Max_Tmp              31.04
# Change_Tmp           10.47
# Mean_Tmp             25.78
# Percipitation       2243.0
# Cases                36795
# SeveralCases             1
# FromMainStates           0
# FromNNECOorSSE           1
# %CasesInPop          4.657
# Name: 2, dtype: object

# %% [markdown]
# ##### **23. Crie um novo DataFrame, após remover a coluna State e verifique se o novo DataFrame ficou conforme o esperado após a exclusão.**

# %%
df_dng_sem_sttrgn = df_dengue.drop('State', axis = 1).copy()

# %%
df_dng_sem_sttrgn.sample(5)
# Out:
#      Year  Population Region  Min_Tmp  Max_Tmp  Change_Tmp  Mean_Tmp  \
# 140  2018   3996496.0     NE    20.11    31.13       11.02     25.59
# 46   2020  14930634.0     NE    19.72    30.61       10.89     25.14
# 45   2019  14873064.0     NE    19.72    31.25       11.53     25.46
# 221  2013   6634254.0      S    12.27    23.03       10.76     17.62
# 120  2016  20997560.0     SE    17.05    29.49       12.44     23.25
#
#      Percipitation   Cases  SeveralCases  FromMainStates  FromNNECOorSSE  \
# 140         662.69   12535             1               0               1
# 46         1024.93  105995             1               0               1
# 45          637.37   84815             1               0               1
# 221        1869.65    1154             0               0               2
# 120        1172.44  666893             1               2               2
#
#      %CasesInPop
# 140     0.313650
# 46      0.709916
# 45      0.570259
# 221     0.017395
# 120     3.176050

# %% [markdown]
# ##### **24. Remova a coluna Region e verifique como o DataFrame ficou.**

# %%
df_dng_sem_sttrgn.drop('Region', axis = 1, inplace=True)
df_dng_sem_sttrgn.sample(3)
# Out:
#      Year  Population  Min_Tmp  Max_Tmp  Change_Tmp  Mean_Tmp  Percipitation  \
# 44   2018  14812617.0    19.55    30.70       11.15     25.10         782.19
# 238  2020  46289333.0    16.91    28.80       11.89     22.83        1061.47
# 164  2021   9674793.0    20.02    30.48       10.46     25.23         590.40
#
#       Cases  SeveralCases  FromMainStates  FromNNECOorSSE  %CasesInPop
# 44    14174             1               0               1     0.095689
# 238  396015             1               0               2     0.855521
# 164      14             0               0               1     0.000145

# %% [markdown]
# ##### **25. Reordene as colunas de modo que FromMainStates seja a segunda, seguida por FromNNEorSSE, depois Population e, finalmente, pode manter a ordem das demais colunas. Em seguida, verifique se as mudanças de ordem persistiram no DataFrame.**

# %%
df_dng_sem_sttrgn = df_dng_sem_sttrgn[['Year',
                       'FromMainStates',
                       'FromNNECOorSSE',
                       'SeveralCases',
                       'Population',
                       'Min_Tmp',
                       'Max_Tmp',
                       'Change_Tmp',
                       'Mean_Tmp',
                       'Percipitation',
                       'Cases']]

# %%
df_dng_sem_sttrgn.tail()
# Out:
#      Year  FromMainStates  FromNNECOorSSE  SeveralCases  Population  Min_Tmp  \
# 254  2017               0               1             1   1550194.0    21.96
# 255  2018               0               1             0   1555229.0    21.81
# 256  2019               0               1             1   1572866.0    21.93
# 257  2020               0               1             0   1590248.0    21.89
# 258  2021               0               1             0   1607363.0    21.62
#
#      Max_Tmp  Change_Tmp  Mean_Tmp  Percipitation  Cases
# 254    33.66       11.70     27.79        1320.86  14882
# 255    33.29       11.48     27.53        1749.54   8236
# 256    33.96       12.03     27.92        1271.12  30901
# 257    33.65       11.76     27.74        1729.92   5625
# 258    33.09       11.47     27.33        1717.39      1

# %%
df_dng_sem_sttrgn.head()
# Out:
#    Year  FromMainStates  FromNNECOorSSE  SeveralCases  Population  Min_Tmp  \
# 0  2012               0               1             0    758786.0    20.48
# 1  2013               0               1             0    776463.0    20.40
# 2  2014               0               1             1    790101.0    20.57
# 3  2015               0               1             1    803513.0    20.88
# 4  2016               0               1             0    816687.0    20.66
#
#    Max_Tmp  Change_Tmp  Mean_Tmp  Percipitation  Cases
# 0    31.05       10.57     25.74        1851.90     22
# 1    30.86       10.46     25.61        1909.14   9229
# 2    31.04       10.47     25.78        2243.00  36795
# 3    31.62       10.74     26.22        1895.83  14320
# 4    31.71       11.05     26.16        1874.84   9237

# %% [markdown]
# ##### **26. Transforme a coluna Year no index do banco de dados.**
#
# > Fazer isso pode deixar o seu banco de dados mais fácil de interpretar e sem uma coluna com números de índice criada automaticamente pela biblioteca Pandas.

# %%
df_dng_sem_sttrgn.set_index('Year', inplace=True)

# %%
df_dng_sem_sttrgn.head()
# Out:
#       FromMainStates  FromNNECOorSSE  SeveralCases  Population  Min_Tmp  \
# Year
# 2012               0               1             0    758786.0    20.48
# 2013               0               1             0    776463.0    20.40
# 2014               0               1             1    790101.0    20.57
# 2015               0               1             1    803513.0    20.88
# 2016               0               1             0    816687.0    20.66
#
#       Max_Tmp  Change_Tmp  Mean_Tmp  Percipitation  Cases
# Year
# 2012    31.05       10.57     25.74        1851.90     22
# 2013    30.86       10.46     25.61        1909.14   9229
# 2014    31.04       10.47     25.78        2243.00  36795
# 2015    31.62       10.74     26.22        1895.83  14320
# 2016    31.71       11.05     26.16        1874.84   9237

# %% [markdown]
# ##### **27. Crie um novo DataFrame com todos os atributos, exceto a coluna FromNNECOorSSE.**
#
# > Quando trabalhamos com Machine Learning / Aprendizado de Máquina, tipicamente, buscamos classificar ou prever um fenômeno, o nosso **alvo** ou *target* ou *label*, em função de um conjunto de **atributos** ou *features*. Para facilitar o nosso trabalho, é útil separar em dois DataFrames distintos target e features.

# %%
features = df_dng_sem_sttrgn.drop('SeveralCases', axis = 1).copy()
features.sample(8)
# Out:
#      Year  FromMainStates  FromNNECOorSSE  Population  Min_Tmp  Max_Tmp  \
# 195  2015               0               2  11247972.0    15.01    24.64
# 176  2014               0               2  16461173.0    17.19    27.98
# 121  2017               2               2  21119536.0    16.87    29.01
# 138  2016               0               1   3999415.0    20.25    31.63
# 88   2013               0               1   6794301.0    22.60    32.59
# 67   2021               1               1   3094325.0    17.15    28.25
# 120  2016               2               2  20997560.0    17.05    29.49
# 43   2017               0               1  15344447.0    19.55    30.62
#
#      Change_Tmp  Mean_Tmp  Percipitation   Cases
# 195        9.63     19.80        2099.02    4131
# 176       10.79     22.56         870.31   15715
# 121       12.14     22.92         974.72   61532
# 138       11.38     25.91         542.79   44958
# 88         9.99     27.57        1393.43    4443
# ...

# %% [markdown]
# ##### **28. Crie um objeto Series apenas com o nosso target, FromNNECOorSSE.**
#
# > Series é um objeto da biblioteca Pandas que possui apenas uma dimensão.

# %%
target = df_dng_sem_sttrgn['SeveralCases'].copy()
target.sample(6)
# Out:
# 190    1
# 183    0
# 168    0
# 185    1
# 139    0
# 197    0
# Name: SeveralCases, dtype: int64

# %% [markdown]
# ##### **29. Transforme os dados da coluna FromMainStates em variáveis dummy.**
#
# > Vários modelos de inteligência artificial, como a Árvore de Decisão, não irão processar valores de texto como os contidos na coluna Region. Felizmente, podemos criar uma coluna para cada região (N, NE, S, SE e CO), que, por exemplo, na coluna da região Norte, conterá o número 1 quando a linha do banco for referente ao Norte e 0, caso contrário.

# %%
features_encoded = pd.get_dummies(features, columns=['FromMainStates']).astype(int)
features_encoded.head()
# Out:
#    Year  FromNNECOorSSE  Population  Min_Tmp  Max_Tmp  Change_Tmp  Mean_Tmp  \
# 0  2012               1      758786       20       31          10        25
# 1  2013               1      776463       20       30          10        25
# 2  2014               1      790101       20       31          10        25
# 3  2015               1      803513       20       31          10        26
# 4  2016               1      816687       20       31          11        26
#
#    Percipitation  Cases  FromMainStates_0  FromMainStates_1  FromMainStates_2  \
# 0           1851     22                 1                 0                 0
# 1           1909   9229                 1                 0                 0
# 2           2243  36795                 1                 0                 0
# 3           1895  14320                 1                 0                 0
# 4           1874   9237                 1                 0                 0
#
#    FromMainStates_3
# ...

# %% [markdown]
# ##### **30. Mude o nome das novas colunas de features criadas, reordene as colunas para as novas ficarem no início do banco e verifique como ficou o DataFrame `features_encoded` após esse conjunto de mudanças.**

# %%
# Mudança de nome das colunas
features_encoded = features_encoded.rename(columns={'FromMainStates_0': 'OtherStates',
                                                    'FromMainStates_1': 'DF',
                                                    'FromMainStates_2': 'MG',
                                                    'FromMainStates_3': 'PR'})

# %%
# Reordenação das colunas
features_encoded = features_encoded[['Year',
                                     'OtherStates',
                                     'DF',
                                     'MG',
                                     'PR',
                                     'FromNNECOorSSE',
                                     'Population',
                                     'Min_Tmp',
                                     'Max_Tmp',
                                     'Change_Tmp',
                                     'Mean_Tmp',
                                     'Percipitation',
                                     'Cases']]

# %%
# Condição final do DataFrame 01 com o qual iremos trabalhar na próxima disciplina
features_encoded.sample(5)
# Out:
#      Year  OtherStates  DF  MG  PR  FromNNECOorSSE  Population  Min_Tmp  \
# 136  2014            1   0   0   0               1     3943885       19
# 219  2019            1   0   0   0               1      605761       22
# 194  2014            1   0   0   0               2    11207274       14
# 213  2013            1   0   0   0               1      488072       21
# 81   2016            1   0   0   0               1     6695855       19
#
#      Max_Tmp  Change_Tmp  Mean_Tmp  Percipitation   Cases
# 136       30          10        25            687    7607
# 219       31           9        26           2564    4173
# 194       24           9        19           2127     783
# 213       31           9        26           2389    2234
# 81        31          12        25           1380  157369

# %%
# Condição final do DataFrame 02 com o qual iremos trabalhar na próxima disciplina
target.to_frame()
# Out:
#      SeveralCases
# 0               0
# 1               0
# 2               1
# 3               1
# 4               0
# ..            ...
# 254             1
# 255             0
# 256             1
# 257             0
# 258             0
#
# [257 rows x 1 columns]

# %%
# Condição final do DataFrame que usaremos nas aulas sobre análise de dados
df_dengue.head()
# Out:
#    Year State  Population Region  Min_Tmp  Max_Tmp  Change_Tmp  Mean_Tmp  \
# 0  2012  Acre    758786.0      N    20.48    31.05       10.57     25.74
# 1  2013  Acre    776463.0      N    20.40    30.86       10.46     25.61
# 2  2014  Acre    790101.0      N    20.57    31.04       10.47     25.78
# 3  2015  Acre    803513.0      N    20.88    31.62       10.74     26.22
# 4  2016  Acre    816687.0      N    20.66    31.71       11.05     26.16
#
#    Percipitation  Cases  SeveralCases  FromMainStates  FromNNECOorSSE  \
# 0        1851.90     22             0               0               1
# 1        1909.14   9229             0               0               1
# 2        2243.00  36795             1               0               1
# 3        1895.83  14320             1               0               1
# 4        1874.84   9237             0               0               1
#
#    %CasesInPop
# 0     0.002899
# 1     1.188595
# 2     4.657000
# 3     1.782174
# 4     1.131033

# %% [markdown]
# ## <font color=green size=6>**TAREFA 02**</font>

# %% [markdown]
# *Esta é a atividade que você fará nas suas horas de aula on-line.*
#
# **01. Usando a base de dados sobre casos de dengue no Brasil, `df_dengue`, crie uma coluna com uma variável categórica baseada no nível de Precipitação. A variável categórica deve ser `HighPercipitation`, contendo 1 para casos de precipitação maiores que a mediana e 0 para casos menores. Entregue o notebook com esta tarefa no Moodle do curso, por meio de um link de compartilhamento.**

# %% [markdown]
# ***
# # <font color=green size=10>**DS-002 - GERENCIAMENTO DE DADOS PARA ANÁLISE - AULA 03**</font>
# ***

# %% [markdown]
# ## <font color=green size=6>**ANÁLISE DE DADOS - ESTATÍSTICA DESCRITIVA BÁSICA**</font>

# %%
# @title Reiniciando notebook
import pandas as pd

dados = pd.read_csv(r'/content/dengue.csv')

df_dengue = pd.DataFrame(dados, columns = ['Year', 'State', 'Population', 'Region', 'Min_Tmp',
                                               'Max_Tmp', 'Change_Tmp', 'Mean_Tmp', 'Percipitation','Cases'])
df_dengue = df_dengue.dropna()

mediana = df_dengue['Cases'].median()
def ident_se_muitos_casos(casos):
  if casos > mediana:
    return 1
  else:
    return 0

df_dengue['SeveralCases'] = df_dengue['Cases'].apply(ident_se_muitos_casos)

def estado_para_cod(estado):
  if estado == 'Distrito Federal':
    return 1
  elif estado == 'Minas Gerais':
    return 2
  elif estado == 'Parana':
    return 3
  else:
    return 0

df_dengue['FromMainStates'] = df_dengue['State'].apply(estado_para_cod)

def div_duas_regioes(regiao):
  if regiao == 'N' or regiao == 'NE' or regiao == 'CO':
    return 1
  else:
    return 2

df_dengue['FromNNECOorSSE'] = df_dengue['Region'].apply(div_duas_regioes)

df_dengue['%CasesInPop'] = (df_dengue['Cases'] / df_dengue['Population'])*100

# %% [markdown]
# ##### **01. Calcule as principais estatísticas descritivas relacionadas ao seu banco de dados.**

# %%
df_dengue.describe()
# Out:
#               Year    Population     Min_Tmp     Max_Tmp  Change_Tmp  \
# count   257.000000  2.570000e+02  257.000000  257.000000  257.000000
# mean   2016.431907  7.754141e+06   19.660856   30.336304   10.675447
# std       2.783221  9.057578e+06    2.570059    2.447473    0.968770
# min    2012.000000  4.695240e+05   12.270000   23.030000    8.320000
# 25%    2014.000000  2.789761e+06   17.750000   28.950000   10.140000
# 50%    2016.000000  3.999415e+06   20.190000   31.010000   10.730000
# 75%    2019.000000  9.345173e+06   21.850000   32.150000   11.280000
# max    2021.000000  4.664913e+07   22.910000   33.960000   13.120000
#
#          Mean_Tmp  Percipitation         Cases  SeveralCases  FromMainStates  \
# count  257.000000     257.000000  2.570000e+02    257.000000      257.000000
# mean    24.973580    1373.148054  4.826914e+04      0.498054        0.233463
# std      2.462505     587.947580  1.171696e+05      0.500972        0.701539
# ...

# %% [markdown]
# > Podemos selecionar as colunas de interesse para a análise.

# %%
df_dengue[['Population',
           'Min_Tmp',
           'Max_Tmp',
           'Change_Tmp',
           'Mean_Tmp',
           'Percipitation',
           'Cases',
           '%CasesInPop']].describe()
# Out:
#          Population     Min_Tmp     Max_Tmp  Change_Tmp    Mean_Tmp  \
# count  2.570000e+02  257.000000  257.000000  257.000000  257.000000
# mean   7.754141e+06   19.660856   30.336304   10.675447   24.973580
# std    9.057578e+06    2.570059    2.447473    0.968770    2.462505
# min    4.695240e+05   12.270000   23.030000    8.320000   17.620000
# 25%    2.789761e+06   17.750000   28.950000   10.140000   23.330000
# 50%    3.999415e+06   20.190000   31.010000   10.730000   25.610000
# 75%    9.345173e+06   21.850000   32.150000   11.280000   26.900000
# max    4.664913e+07   22.910000   33.960000   13.120000   28.000000
#
#        Percipitation         Cases  %CasesInPop
# count     257.000000  2.570000e+02   257.000000
# mean     1373.148054  4.826914e+04     0.590714
# std       587.947580  1.171696e+05     0.759875
# min       328.230000  1.000000e+00     0.000012
# 25%       861.210000  2.604000e+03     0.086169
# 50%      1372.970000  1.149700e+04     0.298391
# ...

# %% [markdown]
# > A notação `e` significa '10 elevado a'. O `+` significa que a potência é positiva e o `02` significa que o número 10 deve ser elevado ao quadrado.

# %% [markdown]
# ##### **02. Calcule a soma de casos de dengue por ano.**

# %%
df_dengue.groupby(by='Year', axis=0)['Cases'].sum()
# Out:
# Year
# 2012        684
# 2013    2011699
# 2014     962070
# 2015    2388234
# 2016    2300972
# 2017     518772
# 2018     478542
# 2019    2265740
# 2020    1477825
# 2021        630
# Name: Cases, dtype: int64

# %% [markdown]
# > 1. Você pode usar o `.sort_values(ascending=True)` para ordernar os valores do menor para o maior caso.
# 2. Você pode usar o `to_frame()` para transformar os resultados para o formato de dataframe.

# %% [markdown]
# ##### **03. Identifique o valor máximo de casos de dengue por estado, ordenando do menor para o maior valor.**

# %%
df_dengue.groupby(by='State',
                  axis=0)['Cases'].max().sort_values().to_frame()
# Out:
#                        Cases
# State
# Amapa                   4434
# Roraima                 4851
# Rio Grande Do Sul       8336
# Piaui                  11243
# Sergipe                14773
# Rondonia               15614
# Para                   19473
# Santa Catarina         23043
# Amazonas               23947
# Maranhao               29890
# Tocantins              30901
# Alagoas                33953
# Acre                   36795
# Paraiba                44958
# Mato Grosso            46693
# Rio Grande Do Norte    63369
# Distrito Federal       64579
# Espirito Santo         83110
# Mato Grosso Do Sul     98924
# Ceara                 105880
# Bahia                 105995
# Pernambuco            172890
# Goias                 200448
# Rio De Janeiro        254654
# Parana                359115
# Minas Gerais          666893
# Sao Paulo            1033012

# %% [markdown]
# ##### **04. Identifique qual o valor mínimo de variação de temperatura e de casos de dengue em função do ano.**

# %%
df_dengue.groupby('Year')[['Change_Tmp', 'Cases']].min()
# Out:
#       Change_Tmp  Cases
# Year
# 2012        9.25      1
# 2013        8.61   1154
# 2014        8.81    676
# 2015        9.01     46
# 2016        8.51   3550
# 2017        8.43   1347
# 2018        8.32     48
# 2019        8.60    915
# 2020        8.70    142
# 2021        8.64      1

# %% [markdown]
# ##### **05. Calcule a média de casos de dengue, por estado, apenas nas linhas do DataFrame em que SeveralCases for igual a 1.**

# %%
df_dengue.query("SeveralCases == 1").groupby('State')['Cases'].mean()
# Out:
# State
# Acre                    19095.400000
# Alagoas                 23647.400000
# Amazonas                19630.500000
# Bahia                   61633.375000
# Ceara                   59314.500000
# Distrito Federal        32416.166667
# Espirito Santo          45699.571429
# Goias                  133084.250000
# Maranhao                29890.000000
# Mato Grosso             28232.714286
# Mato Grosso Do Sul      73109.200000
# Minas Gerais           300759.625000
# Para                    16889.500000
# Paraiba                 25278.000000
# Parana                 115003.375000
# Pernambuco              59001.000000
# Rio De Janeiro          81666.000000
# Rio Grande Do Norte     30478.571429
# Rondonia                14906.000000
# Santa Catarina          18671.000000
# Sao Paulo              445463.750000
# Sergipe                 13153.000000
# Tocantins               21162.400000
# Name: Cases, dtype: float64

# %% [markdown]
# ##### **06. Calcule a média de casos de dengue, por estado, apenas nas linhas do DataFrame em que SeveralCases for igual a 0.**

# %%
df_dengue.query("SeveralCases == 0").groupby('State')['Cases'].mean()
# Out:
# State
# Acre                   4770.600000
# Alagoas                2037.800000
# Amapa                  2103.625000
# Amazonas               6259.375000
# Bahia                     8.500000
# Ceara                     4.000000
# Distrito Federal       2685.750000
# Espirito Santo         3780.500000
# Goias                    31.500000
# Maranhao               4909.875000
# Mato Grosso            3401.000000
# Mato Grosso Do Sul     5525.400000
# Minas Gerais            111.500000
# Para                   7212.400000
# Paraiba                5122.250000
# Parana                   87.000000
# Pernambuco               10.000000
# Piaui                  6693.888889
# Rio De Janeiro         4258.000000
# Rio Grande Do Norte    3177.666667
# Rio Grande Do Sul      3196.777778
# Rondonia               2817.000000
# Roraima                2514.000000
# Santa Catarina         3356.714286
# Sao Paulo               103.500000
# Sergipe                3044.000000
# ...

# %% [markdown]
# ##### **07. Crie um novo DataFrame com esses valores dos Itens 05 e 06.**

# %%
df_sevCases1 = df_dengue.query("SeveralCases == 1").groupby('State')['Cases'].mean()
df_sevCases0 = df_dengue.query("SeveralCases == 0").groupby('State')['Cases'].mean()

# %%
novo_df = pd.concat([df_sevCases1, df_sevCases0],
                        axis=1,
                        keys=['Media_MtsCasos',
                              'Media_PcsCasos'])
novo_df
# Out:
#                      Media_MtsCasos  Media_PcsCasos
# State
# Acre                   19095.400000     4770.600000
# Alagoas                23647.400000     2037.800000
# Amazonas               19630.500000     6259.375000
# Bahia                  61633.375000        8.500000
# Ceara                  59314.500000        4.000000
# Distrito Federal       32416.166667     2685.750000
# Espirito Santo         45699.571429     3780.500000
# Goias                 133084.250000       31.500000
# Maranhao               29890.000000     4909.875000
# Mato Grosso            28232.714286     3401.000000
# Mato Grosso Do Sul     73109.200000     5525.400000
# Minas Gerais          300759.625000      111.500000
# Para                   16889.500000     7212.400000
# Paraiba                25278.000000     5122.250000
# Parana                115003.375000       87.000000
# Pernambuco             59001.000000       10.000000
# Rio De Janeiro         81666.000000     4258.000000
# ...

# %% [markdown]
# ##### **08. Compare as médias de casos de dengue nos cenários com e sem muitos casos.**

# %%
df_dengue.groupby(['SeveralCases', 'State'])['Cases'].mean()
# Out:
# SeveralCases  State
# 0             Acre                     4770.600000
#               Alagoas                  2037.800000
#               Amapa                    2103.625000
#               Amazonas                 6259.375000
#               Bahia                       8.500000
#               Ceara                       4.000000
#               Distrito Federal         2685.750000
#               Espirito Santo           3780.500000
#               Goias                      31.500000
#               Maranhao                 4909.875000
#               Mato Grosso              3401.000000
#               Mato Grosso Do Sul       5525.400000
#               Minas Gerais              111.500000
#               Para                     7212.400000
#               Paraiba                  5122.250000
#               Parana                     87.000000
#               Pernambuco                 10.000000
#               Piaui                    6693.888889
# ...

# %% [markdown]
# ##### **09. Calcule o percentual de casos de dengue superiores à mediana em cada um dos estados que, geralmente, mais possuem casos da doença.**

# %%
df_dengue.groupby('FromMainStates')['SeveralCases'].value_counts(normalize=True).to_frame()
# Out:
#                              proportion
# FromMainStates SeveralCases
# 0              0                0.53304
#                1                0.46696
# 1              1                0.60000
#                0                0.40000
# 2              1                0.80000
#                0                0.20000
# 3              1                0.80000
#                0                0.20000

# %% [markdown]
# 💡**Bônus**
#
# **Pesquise pelo método:**
# - `.crosstab()`: permite cruzar valores e em relação a eles realizar cálculos de frequência, proporção, média, entre outros. A documentação está [aqui](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.crosstab.html).
# - `.cut()`: permite criar intervalos de uma variável quantitativa, associada a cada intervalo um nome. A documentação está aqui [aqui](https://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.cut.html).
# - `variavel.hist(bins=valor, figsize=(x,y))`: permite criar um histograma.
# - `variavel.plot.bar(width=valor, color='nome', figsize=(x,y))`

# %% [markdown]
# ##### **10. Calcule o desvio padrão dos valores de casos de dengue e da variação de temperatura.**

# %%
pd.DataFrame(df_dengue, columns = ['Change_Tmp', 'Cases']).std()
# Out:
# Change_Tmp         0.968770
# Cases         117169.615385
# dtype: float64

# %%
df_dengue[['Change_Tmp', 'Cases']].std()
# Out:
# Change_Tmp         0.968770
# Cases         117169.615385
# dtype: float64

# %% [markdown]
# > Associado ou não ao groupby, **o Pandas nos oferece diversos cálculos estatísticos, tais como:** sum(), mean(), median(), mode(), var(), std(), max(), min(), quantile(0.25), quantile(0.75) e value_counts().
#
# > **Para cálculo de outliers, podemos usar a seguinte estratégia:**
#
# ```
# # Exemplo de DataFrame
# dados = pd.DataFrame({'valores': [10, 15, 20, 25, 30, 100, 105, 110, 115]})
#
# # Cálculo dos quartis
# q1 = dados['valores'].quantile(0.25)
# q3 = dados['valores'].quantile(0.75)
#
# # Cálculo do IQR
# iqr = q3 - q1
#
# # Cálculo dos limites superior e inferior
# limite_inferior = q1 - 1.5 * iqr
# limite_superior = q3 + 1.5 * iqr
#
# # Identificação dos outliers
# outliers = dados[(dados['valores'] < limite_inferior) | (dados['valores'] > limite_superior)]
# ```

# %% [markdown]
# ## <font color=green size=6>**TAREFA 03**</font>

# %% [markdown]
# *Esta é a atividade que você fará nas suas horas de aula on-line.*
#
# **1. Usando a base de dados sobre casos de dengue no Brasil, `df_dengue`, calcule a média de precipitação em cada um dos dois conjuntos de regiões brasileiras (variável `FromNNECOorSSE`) e a quantidade de casos de dengue. Em seguida, faça o mesmo, mas calculando os valores mínimo e máximo.**

# %%
df_dengue.groupby(['SeveralCases' ,'FromNNECOorSSE'])[['Percipitation', 'Cases']].mean()
# Out:
#                              Percipitation          Cases
# SeveralCases FromNNECOorSSE
# 0            1                 1518.780291    3917.223301
#              2                 1565.617308    2651.884615
# 1            1                 1179.024545   46750.340909
#              2                 1300.111750  195467.875000

# %%
df_dengue.groupby(['SeveralCases' ,'FromNNECOorSSE'])[['Percipitation', 'Cases']].min()
# Out:
#                              Percipitation  Cases
# SeveralCases FromNNECOorSSE
# 0            1                      328.23      1
#              2                      901.91      3
# 1            1                      457.63  11533
#              2                      861.21  12346

# %%
df_dengue.groupby(['SeveralCases' ,'FromNNECOorSSE'])[['Percipitation', 'Cases']].max()
# Out:
#                              Percipitation    Cases
# SeveralCases FromNNECOorSSE
# 0            1                     2750.90    11243
#              2                     2320.89    11497
# 1            1                     2602.14   200448
#              2                     2146.55  1033012

# %% [markdown]
# ***
# # <font color=green size=10>**DS-002 - GERENCIAMENTO DE DADOS PARA ANÁLISE - AULA 04**</font>
# ***

# %%
# @title Reiniciando notebook
import pandas as pd

dados = pd.read_csv(r'/content/dengue.csv')

df_dengue = pd.DataFrame(dados, columns = ['Year', 'State', 'Population', 'Region', 'Min_Tmp',
                                               'Max_Tmp', 'Change_Tmp', 'Mean_Tmp', 'Percipitation','Cases'])
df_dengue = df_dengue.dropna()

mediana = df_dengue['Cases'].median()
def ident_se_muitos_casos(casos):
  if casos > mediana:
    return 1
  else:
    return 0

df_dengue['SeveralCases'] = df_dengue['Cases'].apply(ident_se_muitos_casos)

def estado_para_cod(estado):
  if estado == 'Distrito Federal':
    return 1
  elif estado == 'Minas Gerais':
    return 2
  elif estado == 'Parana':
    return 3
  else:
    return 0

df_dengue['FromMainStates'] = df_dengue['State'].apply(estado_para_cod)

def div_duas_regioes(regiao):
  if regiao == 'N' or regiao == 'NE' or regiao == 'CO':
    return 1
  else:
    return 2

df_dengue['FromNNECOorSSE'] = df_dengue['Region'].apply(div_duas_regioes)

df_dengue['%CasesInPop'] = (df_dengue['Cases'] / df_dengue['Population'])*100

# %% [markdown]
# ## <font color=green size=6>**ANÁLISE DE DADOS - ESTATÍSTICA DESCRITIVA INTERMEDIÁRIA**</font>

# %% [markdown]
# ##### **01. Calcule a média de tamanho populacional de cada estado de uma região e, depois, some a população de cada estado, para chegarmos a uma estimativa da população de uma região.**

# %%
dados.groupby(['Region',
               'State'])['Population'].mean().round(2).to_frame().groupby('Region')['Population'].sum().to_frame()
# Out:
#          Population
# Region
# CO      15721047.60
# N       17726136.43
# NE      56529934.13
# S       29533486.44
# SE      86402662.72

# %% [markdown]
# ##### **02. Calcule a correlação entre variáveis importantes do Dataset e que poderão compor o seu modelo.**

# %% [markdown]
# 💡**Um pouco de teoria sobre correlações**
# - **Variável** é qualquer fenômeno cujo valor possa mudar em, pelo menos, dois níveis, estados ou graus. Exemplos de variáveis: temperatura, velocidade, altura, peso, idade, gravidade da doença etc.
# - A **correlação** é uma medida de associação entre duas variáveis. Essa associação pode variar de 0 a 1. Quando o valor é muito próximo de 0, interpretamos que a associação é muita baixa ou inexistente. Por outro lado, quanto mais próximo de 1, interpretamos que existe uma associação entre as variáveis.
# - Uma associação entre a Variável 1 e a Variável 2 pode ser ***diretamente proporcional*** ou ***inversamente proporcional***.
# - A associação diretamente proporcional indica que quanto mais a Variável 1 tem seu valor aumentado, mais isso também é observado na Variável 2 e vice-versa.
# - A associação inversamente proporcional indica que quanto mais a Variável 1 aumenta, mais a Variável 2 reduz o seu valor e vice-versa.
#
# **A imagem a seguir explicita esses dois tipos de relações:**
# ![Tipos de Correlação](https://edtisensei.zendesk.com/hc/article_attachments/360039155971/mceclip1.png)

# %%
df_dengue[['Change_Tmp',
                   'Max_Tmp',
                   'Min_Tmp',
                   'Mean_Tmp',
                   'Percipitation',
                   'Cases',
                   '%CasesInPop']].corr(method='pearson')
# Out:
#                Change_Tmp   Max_Tmp   Min_Tmp  Mean_Tmp  Percipitation  \
# Change_Tmp       1.000000  0.068206 -0.311992 -0.129078      -0.218358
# Max_Tmp          0.068206  1.000000  0.926593  0.980520      -0.077915
# Min_Tmp         -0.311992  0.926593  1.000000  0.982407       0.008110
# Mean_Tmp        -0.129078  0.980520  0.982407  1.000000      -0.034444
# Percipitation   -0.218358 -0.077915  0.008110 -0.034444       1.000000
# Cases            0.266157 -0.148050 -0.241314 -0.199555      -0.093530
# %CasesInPop      0.298783  0.076889 -0.039403  0.017541      -0.005791
#
#                   Cases  %CasesInPop
# Change_Tmp     0.266157     0.298783
# Max_Tmp       -0.148050     0.076889
# Min_Tmp       -0.241314    -0.039403
# Mean_Tmp      -0.199555     0.017541
# Percipitation -0.093530    -0.005791
# Cases          1.000000     0.535874
# %CasesInPop    0.535874     1.000000

# %% [markdown]
# 💡**Bônus**

# %%
from seaborn import heatmap

heatmap(df_dengue[['Change_Tmp',
                   'Max_Tmp',
                   'Min_Tmp',
                   'Mean_Tmp',
                   'Percipitation',
                   'Cases',
                   '%CasesInPop']].corr(method='pearson'),
        cmap='viridis',
        linewidths=.5,
        annot=True)
# Out:
# <Axes: >

# %% [markdown]
# 🤓**Observações importantes:**
#
# - Muitas vezes queremos prever uma variável ou classificar um conjunto de dados usando uma variável. Usamos Aprendizado de Máquina / Inteligência Artificial para fazer isso.
# - Quando você for selecionar variáveis para um modelo de IA, procure evitar manter duas variáveis que estejam fortemente correlacionadas entre si. Essa redundância prejudica o modelo. Tal situação está associada ao conceito de multicolinearidade. Existem técnicas estatísticas para avaliar a existência desse fenômeno. Não obstante, um exame da matriz de correlação pode fornecer indícios da existência desse problema.

# %% [markdown]
# ##### **03. Crie uma figura que exiba a quantidade de casos de dengue ao longo dos anos.**
#
# > É uma boa prática que você insira o título do gráfico e dos eixos x e y. É importante também garantir uma proporção de 7 no eixo y para 10 no eixo x.

# %%
import matplotlib.pyplot as plt

# %%
total_casos_ano = df_dengue.groupby('Year')['Cases'].sum().to_frame()
total_casos_ano
# Out:
#         Cases
# Year
# 2012      684
# 2013  2011699
# 2014   962070
# 2015  2388234
# 2016  2300972
# 2017   518772
# 2018   478542
# 2019  2265740
# 2020  1477825
# 2021      630

# %%
# Tamanho da figura
plt.figure(figsize=(10,6))

# Título da figura
plt.title('Quantidade de casos de Dengue por Ano\n2012 a 2021', fontweight='bold')

# Título do eixo x
plt.xlabel('Anos')

# Tìtulo do eixo y
plt.ylabel('Quantidade')

# Inserção dos dados
plt.plot(total_casos_ano.index, total_casos_ano['Cases'])

# Definição dos elementos do eixo x
plt.xticks([2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021])

# Definição dos elementos do eixo y
plt.yticks([0, 500000, 1000000, 1500000, 2000000, 2500000])

# Código para que seja exibido apenas o gráfico
plt.show()

# %% [markdown]
# ##### **04. Crie um gráfico interativo com a somatória de casos de dengue por ano e por estados com mais casos de dengue (variável `FromMainStates`).**

# %%
cases_year_mainstates = df_dengue.groupby(['Year', 'FromMainStates'])[['Cases']].sum()
cases_year_mainstates = cases_year_mainstates.pivot_table(index='Year', columns='FromMainStates', values='Cases', aggfunc='first')
cases_year_mainstates = cases_year_mainstates.reset_index()
cases_year_mainstates = cases_year_mainstates.set_index('Year')

# %%
import plotly.express as px

fig = px.line(cases_year_mainstates,
              x=cases_year_mainstates.index,
              y=cases_year_mainstates.columns,
              title='Quantidade de Casos de Dengue em Estados com histórico de maior gravidade por Ano',
              markers=True)
fig.update_layout(width=1000, height=650,
                  xaxis={'tickangle':-45},
                  xaxis_title='Ano',
                  yaxis_title='Quantidade')

fig.update_traces(line_width=3.5)

fig.update_xaxes(tickvals=[2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.write_html('DadosDengue.html')

# %% [markdown]
# ## <font color=green size=6>**TAREFA 04**</font>

# %% [markdown]
# *Esta é a atividade que você fará nas suas horas de aula on-line.*
#
# **1. Usando a base de dados sobre casos de dengue no Brasil, `df_dengue`, tente identificar uma nova variável, não utilizada no exemplo de sala de aula ou que você consiga gerar a partir dos dados do banco e cuja correlação com casos de dengue, `Cases`, ou com `%CasesInPop` seja 0,20 a 0,30 (positivo ou negativo).**

# %% [markdown]
# ***
# # <font color=green size=10>**DS-03 - ANÁLISES BÁSICAS DE DADOS PARA ÁREA DA SAÚDE I - AULA 01**</font>
# ***

# %% [markdown]
# ### **Informações importantes**
#
# **CART** é o algoritmo mais clássico para a geração de árvores de decisão capazes de classificar fenômenos. Em geral, para construirmos uma árvore, precisamos descobrir de que modos podemos "separar" os nossos dados de modo a reduzir o grau de impureza.
#
# Dizer isso significa que precisamos descobrir como separar os dados de modo que possamos chegar a uma classificação perfeita (pura). Para chegar ao melhor resultado possível nesse sentido é que existe o algoritmo de geração da árvore.
#
# **No geral, o algoritmo faz o seguinte:**
# 1. **Qual é o nó raiz da árvore?** Temos que identificar qual será o atributo que fará a melhor divisão da árvore, reduzindo ao máximo a impureza.
# 2. **Precisamos reduzir ainda mais a impureza?** Se sim, podemos adotar a mesma estratégia do primeiro passo. Saberemos que não é mais necessário reduzir a impureza quando chegarmos a uma folha pura ou quando, por um critério que definirmos, como tamanho máximo da árvore, não pudermos mais seguir reduzindo a impureza de um ou mais nós.
# 3. **Índice de impureza de Gini para determinação do grau de impureza:**
#
# $$
# Gini = 1 - \sum_{i=1}^{n} p_i^{2}
# $$
#
# **Atenção:** temos casos em que não queremos classificar um fenômeno de modo binário, mas prever um valor contínuo ou uma probabilidade de 0 a 100%. Para tanto, temos as árvores de regressão.
#
# **A ideia geral do algoritmo não é tão diferente, pois queremos encontrar um nó que divida melhor os dados:**
# 1. Um nó, de acordo com um critério categórico ou contínuo, separará um conjunto de valores à esquerda e à direita. Calcula-se, então, uma média aritmética desses valores da esquerda e da direita.
# 2. Ao comparar as várias possibilidades de nós, queremos aquele cuja somatória das diferenças entre dados individuais e as médias que calculamos, seja a menor possível.
# 3. **Soma dos Quadrados dos Resíduos (RSS):**
#
# $$
# RSS = \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^{2}
# $$

# %% [markdown]
# ## <font color=green size=6>**ÁRVORE DE DECISÃO - CLASSIFICAÇÃO**</font>

# %% [markdown]
# ##### **01. Exemplo simples de classificação - Importação de bibliotecas.**

# %%
# !pip install -U scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 33.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ...

# %%
# Recurso para trabalharmos com "tabelas com dados" / Dataframes
import pandas as pd

# Recurso para divisão dos dados em treino e teste
from sklearn.model_selection import train_test_split

# Recurso para criação de árvore de decisão capaz de classificar dados
from sklearn.tree import DecisionTreeClassifier, plot_tree

# Recursos para exibição da árvore de decisão
import matplotlib.pyplot as plt

# Recursos para cálculo e exibição da matriz de confusão
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay

# %% [markdown]
# ##### **02. Exemplo simples de classificação - Criação do dataframe.**

# %%
# Criação do conjunto de dados
dados = {
    'Brasileiro': [1, 0, 1, 1, 0],
    'VacinadoCovid': [1, 0, 1, 0, 0],
    'Idade': [12, 33, 18, 22, 18],
    'Fraude': [0, 1, 0, 1, 0]
}

# %%
# Criação do dataframe a partir do conjunto de dados
fraudeCartaoVacina = pd.DataFrame(dados)
fraudeCartaoVacina
# Out:
#    Brasileiro  VacinadoCovid  Idade  Fraude
# 0           1              1     12       0
# 1           0              0     33       1
# 2           1              1     18       0
# 3           1              0     22       1
# 4           0              0     18       0

# %% [markdown]
# ##### **03. Exemplo simples de classificação - Separação dos dados de treino e de teste a partir do dataframe criado.**

# %%
# Criação do dataframe com os atributos usados para a classificação
features = fraudeCartaoVacina.drop('Fraude', axis = 1)
features
# Out:
#    Brasileiro  VacinadoCovid  Idade
# 0           1              1     12
# 1           0              0     33
# 2           1              1     18
# 3           1              0     22
# 4           0              0     18

# %%
# Criação da series com as categorias de classificação
label = fraudeCartaoVacina['Fraude']
label
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# Name: Fraude, dtype: int64

# %%
# Código para divisão da base de dados em treino e teste
# Normalmente reservamos de 20% a 30% dos dados para teste
features_train, features_test, label_train, label_test = train_test_split(
    features, label, test_size = 0.4, random_state = 1
)

# %%
features_train
# Out:
#    Brasileiro  VacinadoCovid  Idade
# 4           0              0     18
# 0           1              1     12
# 3           1              0     22

# %%
features_test
# Out:
#    Brasileiro  VacinadoCovid  Idade
# 2           1              1     18
# 1           0              0     33

# %%
label_train
# Out:
# 4    0
# 0    0
# 3    1
# Name: Fraude, dtype: int64

# %%
label_test
# Out:
# 2    0
# 1    1
# Name: Fraude, dtype: int64

# %% [markdown]
# ##### **04. Exemplo simples de classificação - Criação da árvore de decisão.**

# %%
# 'Tree' é criado como um elemento do tipo Árvore, tendo todas as suas
# propriedades e capacidades
tree = DecisionTreeClassifier()

# O método fit da Árvore realiza o treinamento e os resultados
# ficaram guarados em um novo elemento do tipo Árvore, que optei por criar.
# Trata-se do 'tree_trained'.
tree_trained = tree.fit(features_train, label_train)

# %% [markdown]
# ##### **05. Exemplo simples de classificação - Exibição da árvore.**

# %%
import matplotlib.pyplot as plt  # Importando o pyplot do matplotlib

# Criação do espaço no qual a árvore será criada
plt.figure(figsize=(15, 7.5))  # pyplot.figure

# Exibição da árvore sobre o espaço criado
plot_tree(tree_trained,
         filled=True,
         rounded=True,
         class_names=["Não", "Sim"],
         feature_names=features.columns);

plt.show()  # Mostrando o gráfico

# %% [markdown]
# ##### **06. Exemplo simples de classificação - Cálculo e exibição da matriz de confusão.**

# %%
# Criação das predições com base nos atributos separados para teste
label_pred = tree_trained.predict(features_test)
label_pred
# Out:
# array([0, 1])

# %%
# Cálculo da matriz de confusão comparando os dados reais separados
# para teste e as previsões de classificação geradas pelo modelo
# em função dos atributos de teste que informamos
cm = confusion_matrix(label_test, label_pred)
cm
# Out:
# array([[1, 0],
#        [0, 1]])

# %%
# Exeibição da matriz de confusão
display_cm = ConfusionMatrixDisplay(confusion_matrix = cm,
                                    display_labels = ["Não", "Sim"])
display_cm.plot(cmap='viridis')

# %% [markdown]
# ## <font color=green size=6>**TAREFA 01**</font>

# %% [markdown]
# **1. Crie dados fictícios relativos a algum assunto do seu interesse, mas que envolva o tema da saúde. Em seguida, repita os passos que já adotamos para criar uma árvore de decisão simples e que tenha por finalidade classificar algum processo ou fenômeno, usando apenas 02 categorias (exe.: sim e não, presente e ausente, bom e ruim etc.).**

# %%
# !pip install -U scikit-learn

# %%
# Importar bibliotecas necessárias
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
# Criação do conjunto de dados
infos = {
    'Idade': [25, 30, 22, 35, 40, 28, 32, 23, 45, 37],
    'IMC': [22.5, 27.3, 19.8, 24.5, 29.1, 26.5, 23.3, 20.2, 31.4, 28.9],
    'Freq_Exercicios': [4, 2, 5, 3, 1, 3, 4, 5, 0, 2],
    'Dieta_Balanceada': [1, 0, 1, 0, 0, 1, 1, 1, 0, 0],
    'Horas_Sono': [7.5, 6.0, 8.0, 7.0, 5.5, 7.5, 7.0, 8.0, 6.0, 6.5],
    'Saudável': [1, 0, 1, 0, 0, 1, 1, 1, 0, 0]
}

# %%
# Criação da série com as categorias de classificação
label = saude['Saudável']
print(label)
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# 5    1
# 6    1
# 7    1
# 8    0
# 9    0
# Name: Saudável, dtype: int64

# %%
# Código para divisão da base de dados em treino e teste
features_train, features_test, label_train, label_test = train_test_split(
    features, label, test_size=0.4, random_state=1
)

# %%
# Exibir dados de treino e teste
print(features_train)
print(features_test)
print(label_train)
print(label_test)
# Out:
#    Idade   IMC  Freq_Exercicios  Dieta_Balanceada  Horas_Sono
# 0     25  22.5                4                 1         7.5
# 3     35  24.5                3                 0         7.0
# 1     30  27.3                2                 0         6.0
# 7     23  20.2                5                 1         8.0
# 8     45  31.4                0                 0         6.0
# 5     28  26.5                3                 1         7.5
#    Idade   IMC  Freq_Exercicios  Dieta_Balanceada  Horas_Sono
# 2     22  19.8                5                 1         8.0
# 9     37  28.9                2                 0         6.5
# 6     32  23.3                4                 1         7.0
# 4     40  29.1                1                 0         5.5
# 0    1
# 3    0
# 1    0
# 7    1
# 8    0
# 5    1
# Name: Saudável, dtype: int64
# 2    1
# 9    0
# 6    1
# 4    0
# Name: Saudável, dtype: int64

# %%
# Criação da árvore de decisão
tree = DecisionTreeClassifier()

# %%
# Treinamento da árvore de decisão
tree_trained = tree.fit(features_train, label_train)

# %%
# Criação do espaço no qual a árvore será criada
plt.figure(figsize=(15, 7.5))

# %%
# Exibição da árvore sobre o espaço criado
plot_tree(tree_trained,
          filled=True,
          rounded=True,
          class_names=["Não Saudável", "Saudável"],
          feature_names=features.columns)

plt.show()

# %%
# Criação das predições com base nos atributos separados para teste
label_pred = tree_trained.predict(features_test)
print(label_pred)
# Out:
# [1 0 1 0]

# %%
# Cálculo da matriz de confusão comparando os dados reais separados
# para teste e as previsões de classificação geradas pelo modelo
cm = confusion_matrix(label_test, label_pred)
print(cm)
# Out:
# [[2 0]
#  [0 2]]

# %%
# Exibição da matriz de confusão
display_cm = ConfusionMatrixDisplay(confusion_matrix=cm,
                                    display_labels=["Não Saudável", "Saudável"])
display_cm.plot(cmap='viridis')
plt.show()
