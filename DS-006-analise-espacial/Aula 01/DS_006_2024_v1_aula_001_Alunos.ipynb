# %% [markdown]
# # **Disciplina: DS-006**
# **Aula: 001**
#
# Topicos abordados:
#
# * Introdução a Geovisualização
# * Introdução ao geopandas
# * Plot por estados do Brasil

# %%
"""
Biblioteca inical para manipulação de dados
"""
import pandas as pd

# %% [markdown]
# Dados relacionados a **Febre Amarela em humanos e primatas não-humanos - 1994 a 2023**
#
# Dataset a ser utilizado foi obtido em: https://opendatasus.saude.gov.br/dataset/febre-amarela-em-humanos-e-primatas-nao-humanos
#
# Descrição dos dataset: https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/Febre+Amarela/Dicionario+de+variaveis.pdf

# %%
"""
Lendo o dataset
"""
url = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/Febre+Amarela/fa_casoshumanos_1994-2023.csv'
# TODO: Ler o arquivo csv utilizando a codificação ISO-8859-1 e o delimitador de
# dados como ";"

df = pd.read_csv(
    url,  # Corrigido: Adicionando o parâmetro url
    encoding='ISO-8859-1',
    sep=';'
)

# %% [markdown]
# **Conhecendo o dataset**

# %%
"""
Descrição dos dataset: https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/Febre+Amarela/Dicionario+de+variaveis.pdf
"""
df.head()
# Out:
#    ID MACRORREG_LPI  COD_UF_LPI UF_LPI  COD_MUN_LPI                MUN_LPI  \
# 0   1             N          14     RR     140005.0            ALTO ALEGRE
# 1   2             N          14     RR     140045.0              PACARAIMA
# 2   3            NE          21     MA     210060.0   AMARANTE DO MARANHÃO
# 3   4            NE          21     MA     210060.0   AMARANTE DO MARANHÃO
# 4   5             N          15     PA     150270.0  CONCEIÇÃO DO ARAGUAIA
#
#   SEXO IDADE       DT_IS  SE_IS  MES_IS  ANO_IS MONITORAMENTO_IS OBITO  \
# 0    M   NaN  29/11/1994   48.0    11.0    1994        1994/1995   SIM
# 1    M    19  19/02/1995    8.0     2.0    1995        1994/1995   NÃO
# 2    M    32  01/04/1995   13.0     4.0    1995        1994/1995   IGN
# 3    M    33  03/04/1995   14.0     4.0    1995        1994/1995   SIM
# 4    M    26  12/04/1995   15.0     4.0    1995        1994/1995   SIM
#
#      DT_OBITO
# 0  01/12/1994
# 1         NaN
# 2         NaN
# 3  09/04/1995
# 4  20/04/1995

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2768 entries, 0 to 2767
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                2768 non-null   int64
#  1   MACRORREG_LPI     2768 non-null   object
#  2   COD_UF_LPI        2768 non-null   int64
#  3   UF_LPI            2768 non-null   object
#  4   COD_MUN_LPI       2761 non-null   float64
#  5   MUN_LPI           2762 non-null   object
#  6   SEXO              2767 non-null   object
#  7   IDADE             2766 non-null   object
#  8   DT_IS             2763 non-null   object
#  9   SE_IS             2752 non-null   float64
#  10  MES_IS            2757 non-null   float64
#  11  ANO_IS            2768 non-null   int64
#  12  MONITORAMENTO_IS  2768 non-null   object
#  13  OBITO             2768 non-null   object
#  14  DT_OBITO          979 non-null    object
# dtypes: float64(3), int64(3), object(9)
# memory usage: 324.5+ KB

# %%
df.shape
# Out:
# (2768, 15)

# %%
#Substituindo o NaN e valores vazios por 0 e removendo valores como string

# Replace NaN and empty values with 0
df["IDADE"] = df["IDADE"].fillna(0)
df["IDADE"] = df["IDADE"].replace('', 0)

# Removendo valores string e convertendo para inteiro
df["IDADE"] = pd.to_numeric(df["IDADE"], errors='coerce').fillna(0).astype(int)

# %%
"""
Obtendo a média de idade dos casos
"""
# TODO: Obter a média das idades
df["IDADE"]
# Out:
# 0        0
# 1       19
# 2       32
# 3       33
# 4       26
#         ..
# 2763    12
# 2764    16
# 2765    44
# 2766    44
# 2767    38
# Name: IDADE, Length: 2768, dtype: int64

# %%
# Ordenando o dataframe
df_ordenado = df.sort_values('UF_LPI')
df_ordenado.head()

# Conhecendo os códigos do municipios: https://www.ibge.gov.br/explica/codigos-dos-municipios.php
# Out:
#         ID MACRORREG_LPI  COD_UF_LPI UF_LPI  COD_MUN_LPI  \
# 2735  2736             N          12     AC     120001.0
# 216    217             N          12     AC     120038.0
# 336    337             N          13     AM     130440.0
# 28      29             N          13     AM     130353.0
# 2727  2728             N          13     AM     130130.0
#
#                     MUN_LPI SEXO  IDADE       DT_IS  SE_IS  MES_IS  ANO_IS  \
# 2735             ACRELÂNDIA    M     16  30/01/2020    5.0     1.0    2020
# 216       PLÁCIDO DE CASTRO    M     21  29/06/2000   26.0     6.0    2000
# 336             URUCURITUBA    F     16  13/05/2003   20.0     5.0    2003
# 28    PRESIDENTE FIGUEIREDO    F     17  28/02/1998    8.0     2.0    1998
# 2727                CODAJÁS    M     21  28/02/2019    9.0     2.0    2019
#
#      MONITORAMENTO_IS OBITO    DT_OBITO
# 2735        2019/2020   SIM  10/02/2020
# 216         1999/2000   NÃO         NaN
# 336         2001/2002   NÃO         NaN
# 28          1997/1998   NÃO         NaN
# 2727        2018/2019   NÃO         NaN

# %%
df
# Out:
#         ID MACRORREG_LPI  COD_UF_LPI UF_LPI  COD_MUN_LPI  \
# 0        1             N          14     RR     140005.0
# 1        2             N          14     RR     140045.0
# 2        3            NE          21     MA     210060.0
# 3        4            NE          21     MA     210060.0
# 4        5             N          15     PA     150270.0
# ...    ...           ...         ...    ...          ...
# 2763  2764             N          13     AM     130280.0
# 2764  2765             N          13     AM     130250.0
# 2765  2766            SE          35     SP     355080.0
# 2766  2767            SE          35     SP     354910.0
# 2767  2768             N          14     RR     140047.0
#
#                      MUN_LPI SEXO  IDADE       DT_IS  SE_IS  MES_IS  ANO_IS  \
# 0                ALTO ALEGRE    M      0  29/11/1994   48.0    11.0    1994
# 1                  PACARAIMA    M     19  19/02/1995    8.0     2.0    1995
# 2       AMARANTE DO MARANHÃO    M     32  01/04/1995   13.0     4.0    1995
# 3       AMARANTE DO MARANHÃO    M     33  03/04/1995   14.0     4.0    1995
# 4      CONCEIÇÃO DO ARAGUAIA    M     26  12/04/1995   15.0     4.0    1995
# ...                      ...  ...    ...         ...    ...     ...     ...
# 2763                   MARAÃ    M     12  14/02/2023    7.0     2.0    2023
# 2764              MANACAPURU    M     16  02/04/2023   14.0     4.0    2023
# 2765  SÃO SEBASTIÃO DA GRAMA    M     44  18/02/2023    7.0     2.0    2023
# 2766   SÃO JOÃO DA BOA VISTA    M     44  25/04/2023   17.0     4.0    2023
# 2767            RORAINÓPOLIS    M     38  27/08/2023   35.0     8.0    2023
#
#      MONITORAMENTO_IS OBITO    DT_OBITO
# 0           1994/1995   SIM  01/12/1994
# 1           1994/1995   NÃO         NaN
# 2           1994/1995   IGN         NaN
# 3           1994/1995   SIM  09/04/1995
# 4           1994/1995   SIM  20/04/1995
# ...               ...   ...         ...
# 2763        2022/2023   NÃO         NaN
# 2764        2022/2023   SIM  13/04/2023
# 2765        2022/2023   NÃO         NaN
# 2766        2022/2023   SIM  30/04/2023
# 2767        2023/2024   SIM  31/08/2023
#
# [2768 rows x 15 columns]

# %%
"""
Seleção de colunas para manipulação dos dados
Criando um novo data frame usando df_ordenado que contenha as colunas:
UF_LPI, MUN_LPI, SEXO, IDADE, ANO_IS, OBITO e redefinindo o index do data frame
"""

novo_df = df_ordenado[['UF_LPI', 'MUN_LPI', 'SEXO', 'IDADE', 'ANO_IS', 'OBITO']].reset_index(drop=True)
novo_df.head()
# Out:
#   UF_LPI                MUN_LPI SEXO  IDADE  ANO_IS OBITO
# 0     AC             ACRELÂNDIA    M     16    2020   SIM
# 1     AC      PLÁCIDO DE CASTRO    M     21    2000   NÃO
# 2     AM            URUCURITUBA    F     16    2003   NÃO
# 3     AM  PRESIDENTE FIGUEIREDO    F     17    1998   NÃO
# 4     AM                CODAJÁS    M     21    2019   NÃO

# %%
# Conhecendo a biblioteca GEOBR: https://ipeagit.github.io/geobr/articles/python-intro/py-intro-to-geobr.html
# Instalando geobr
# !pip install geobr
# Out:
# Collecting geobr
#   Downloading geobr-0.2.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: geopandas<0.15.0,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from geobr) (0.14.4)
# Collecting lxml<6.0.0,>=5.1.0 (from geobr)
#   Downloading lxml-5.3.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: requests<3.0.0,>=2.25.1 in /usr/local/lib/python3.10/dist-packages (from geobr) (2.32.3)
# Collecting shapely<2.0.0,>=1.7.0 (from geobr)
#   Downloading Shapely-1.8.5.post1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: fiona>=1.8.21 in /usr/local/lib/python3.10/dist-packages (from geopandas<0.15.0,>=0.14.0->geobr) (1.9.6)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from geopandas<0.15.0,>=0.14.0->geobr) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas<0.15.0,>=0.14.0->geobr) (24.1)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from geopandas<0.15.0,>=0.14.0->geobr) (2.1.4)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from geopandas<0.15.0,>=0.14.0->geobr) (3.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.25.1->geobr) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.25.1->geobr) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.25.1->geobr) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.25.1->geobr) (2024.8.30)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.21->geopandas<0.15.0,>=0.14.0->geobr) (24.2.0)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.21->geopandas<0.15.0,>=0.14.0->geobr) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.21->geopandas<0.15.0,>=0.14.0->geobr) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.21->geopandas<0.15.0,>=0.14.0->geobr) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.21->geopandas<0.15.0,>=0.14.0->geobr) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->geopandas<0.15.0,>=0.14.0->geobr) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->geopandas<0.15.0,>=0.14.0->geobr) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.0->geopandas<0.15.0,>=0.14.0->geobr) (2024.1)
# Downloading geobr-0.2.1-py3-none-any.whl (33 kB)
# Downloading lxml-5.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 37.7 MB/s eta 0:00:00
# Downloading Shapely-1.8.5.post1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 61.9 MB/s eta 0:00:00
# Installing collected packages: shapely, lxml, geobr
#   Attempting uninstall: shapely
#     Found existing installation: shapely 2.0.6
#     Uninstalling shapely-2.0.6:
#       Successfully uninstalled shapely-2.0.6
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.9.4
#     Uninstalling lxml-4.9.4:
#       Successfully uninstalled lxml-4.9.4
# Successfully installed geobr-0.2.1 lxml-5.3.0 shapely-1.8.5.post1

# %%
import geobr

# %%
# Manipulação de graficos
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Obtendo os dados do estado de Roraima
state = geobr.read_state(code_state="RR")
state
# Out:
#    code_state abbrev_state name_state  code_region name_region  \
# 0        14.0           RR    Roraima          1.0       Norte
#
#                                             geometry
# 0  MULTIPOLYGON (((-60.20051 5.26434, -60.19273 5...

# %%
# TODO: Obter os dados dos municipio de Roraima
muni = geobr.read_state(code_state="RR")
muni
# Out:
#    code_state abbrev_state name_state  code_region name_region  \
# 0        14.0           RR    Roraima          1.0       Norte
#
#                                             geometry
# 0  MULTIPOLYGON (((-60.20051 5.26434, -60.19273 5...

# %%
# Convertendo para lower case a coluna MUN_LPI para padronizar a comparação

novo_df['MUN_LPI'] = novo_df['MUN_LPI'].str.lower() # converte a coluna MUN_LPI para lower case
novo_df['MUN_LPI']
# Out:
# 0                  acrelândia
# 1           plácido de castro
# 2                 urucurituba
# 3       presidente figueiredo
# 4                     codajás
#                 ...
# 2763                    almas
# 2764            campos lindos
# 2765                  arraias
# 2766            campos lindos
# 2767            campos lindos
# Name: MUN_LPI, Length: 2768, dtype: object

# %%
# Renderizando o municipio de ???
# Renderizando o municipio de Roraima
muni['geometry'][0]

# %%
# Download all municipalities of Rio
all_muni = geobr.read_municipality(code_muni="RR", year=2010)

# plot
fig, ax = plt.subplots(figsize=(10, 7), dpi=300)

# 'tab20' para ter uma variedade de 20 cores distintas
all_muni.plot(column='name_muni', cmap='tab20', edgecolor="black", linewidth=0.8, ax=ax)

ax.set_title("Municipios de Roraima", fontsize=20)
ax.axis("off")
# Out:
# (-65.12217216952395, -58.5899659292567, -1.9232568160652506, 5.614464786450802)

# %%
# Descrição do geodataframe
muni.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   code_muni     102 non-null    float64
#  1   name_muni     102 non-null    object
#  2   code_state    102 non-null    float64
#  3   abbrev_state  102 non-null    object
#  4   geometry      102 non-null    geometry
# dtypes: float64(2), geometry(1), object(2)
# memory usage: 4.1+ KB

# %%
# Descrição do Sistema de Georeferência
muni.crs
# Out:
# <Geographic 2D CRS: EPSG:4674>
# Name: SIRGAS 2000
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: Latin America - Central America and South America - onshore and offshore. Brazil - onshore and offshore.
# - bounds: (-122.19, -59.87, -25.28, 32.72)
# Datum: Sistema de Referencia Geocentrico para las AmericaS 2000
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
# TODO: Obter a area dos poligonos que representam os Estados

# %%
# TODO: Obter a descrição dos limites ou stringline dos Estados

# %%
# TODO: Criar um mapa usando as áreas calculadas

# %% [markdown]
# ---
# # **FIM da aula 001**
#
# ---

# %%
boa_vista = all_muni[all_muni['name_muni'] == 'Boa Vista']

# Plotando o mapa
fig, ax = plt.subplots(figsize=(10, 7), dpi=300)
boa_vista.plot(column='name_muni', color='#1dff96', edgecolor="black", linewidth=0.8, ax=ax)
ax.set_title("Município de Boa Vista - Roraima", fontsize=20)
ax.axis("off")
plt.show()
# Out:
# <ipython-input-69-5d506797d585>:6: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   boa_vista.plot(column='name_muni', color='#1dff96', edgecolor="black", linewidth=0.8, ax=ax)

# %%
# Plot all Brazilian states
fig, ax = plt.subplots(figsize=(15, 15), dpi=300)

states.plot(facecolor="#2D3E50", edgecolor="#FEBF57", ax=ax)

ax.set_title("States", fontsize=20)
ax.axis("off")
# Out:
# (-76.24758052684999, -26.59070825415, -35.70232894755001, 7.222992030549992)

# %%
import matplotlib.pyplot as plt
# Plot all Brazilian states with different colors
fig, ax = plt.subplots(figsize=(15, 15), dpi=300)

states.plot(column='name_state', cmap='tab20', edgecolor="black", linewidth=0.8, ax=ax)

ax.set_title("States", fontsize=20)
ax.axis("off")
# Out:
# (-76.24758052684999, -26.59070825415, -35.70232894755001, 7.222992030549992)
